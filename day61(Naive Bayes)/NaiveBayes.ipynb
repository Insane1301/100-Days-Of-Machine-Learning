# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('PlayTennis.csv')
data.head()
# Out:
#     Outlook Temperature Humidity    Wind Play Tennis
# 0     Sunny         Hot     High    Weak          No
# 1     Sunny         Hot     High  Strong          No
# 2  Overcast         Hot     High    Weak         Yes
# 3      Rain        Mild     High    Weak         Yes
# 4      Rain        Cool   Normal    Weak         Yes

# %%
# Problem 1 
# outlook - sunny, Humidity- high, wind - weak
# play or not

# %%
# solution

# p(yes/ sunny,hot,high,weak) = p(sunny/yes) * p(hot/yes) * p(high/yes) * p(weak/yes) * p(yes)

# p(No/ sunny,hot,high,weak) = p(sunny/No) * p(hot/No) * p(high/No) * p(weak/No) * p(No)

#  compare and decinde Maximum a posterior rule

# %%
# Problem 2 
# outlook - overcast,temp = cold, Humidity- low, wind - weak
# play or not

# %%
# solution

# p(yes/ overcast,cold,high,weak) = p(overcast/yes) * p(cold/yes) * p(high/yes) * p(weak/yes) * p(yes)

# p(No/ overcast,cold,high,weak) = p(overcast/No) * p(cold/No) * p(high/No) * p(weak/No) * p(No)

#  compare and decinde Maximum a posterior rule

# %%
# Training

# Lookup table (disctionary)

# Testing

# %%
# P(Yes)
# P(No)

# %%
data['Play Tennis'].value_counts()
# Out:
# Play Tennis
# Yes    9
# No     5
# Name: count, dtype: int64

# %%
py = 9/14
pn = 5/14

# %%
py
# Out:
# 0.6428571428571429

# %%
pn
# Out:
# 0.35714285714285715

# %%
# Outlook
pd.crosstab(data['Outlook'],data['Play Tennis'])
# Out:
# Play Tennis  No  Yes
# Outlook
# Overcast      0    4
# Rain          2    3
# Sunny         3    2

# %%
Pon = 0
Prn = 2/5
Psn = 3/5

Poy = 4/9
Pry = 3/9
Psy = 2/9

# %%
# Outlook
pd.crosstab(data['Temperature'],data['Play Tennis'])
# Out:
# Play Tennis  No  Yes
# Temperature
# Cool          1    3
# Hot           2    2
# Mild          2    4

# %%
PCoolNo = 1/5
PHotNo = 2/5
PMildNo = 2/5

PCoolYes = 3/9
PHotYes = 2/9
PMildYes = 4/9

# %%
# Outlook
pd.crosstab(data['Humidity'],data['Play Tennis'])
# Out:
# Play Tennis  No  Yes
# Humidity
# High          4    3
# Normal        1    6

# %%
PhighNo = 4/5
Pnormalno = 1/5

Phighyes = 3/9
Pnormalyes = 6/9

# %%
# Outlook
pd.crosstab(data['Wind'],data['Play Tennis'])
# Out:
# Play Tennis  No  Yes
# Wind
# Strong        3    3
# Weak          2    6

# %%
Pstrongno = 3/5
pweakno = 2/5

Pstrongyes = 3/9
pweakyes = 6/9

# %%
# outlook - sunny, Humidity- high, wind - weak

pyes = py*Psy*PHotYes*Phighyes*pweakyes
pyes
# Out:
# 0.007054673721340388

# %%
# outlook - overcast,temp = cold, Humidity- low, wind - weak
pno = pn*Psn*PHotNo*PhighNo*pweakno
pno
# Out:
# 0.02742857142857143

# %%
# No Play
