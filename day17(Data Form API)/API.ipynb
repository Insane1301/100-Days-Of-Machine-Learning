# %% [markdown]
# ### Working With API

# %%
import requests
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=154645b9b75f6895cc2c81b972f4b037&language=en-US&page=1')

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     29.7348
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     26.9596
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     15.0310
# 3  The true story of how businessman Oskar Schind...   1993-12-15     16.8997
# 4  The defense and the prosecution have rested an...   1957-04-10     11.6829
#
#    vote_average  vote_count
# 0         8.715       29633
# 1         8.687       22382
# 2         8.570       13538
# 3         8.566       17059
# 4         8.554        9701

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import time

session = requests.Session()
all_dfs = []

for i in range(1, total_pages + 1):
    response = session.get(
        "https://api.themoviedb.org/3/movie/top_rated",
        params={
            "api_key": "YOUR_API_KEY",
            "language": "en-US",
            "page": i
        },
        timeout=10
    )

    data = response.json()

    # ✅ Safety check
    if 'results' not in data:
        print(f"Stopping at page {i} | API response:", data)
        break

    temp_df = pd.DataFrame(data['results'])[
        ['id','title','overview','release_date','popularity','vote_average','vote_count']
    ]

    all_dfs.append(temp_df)
    time.sleep(0.2)  # avoid throttling

df = pd.concat(all_dfs, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 6
#       3 session = requests.Session()
#       4 all_dfs = []
# ----> 6 for i in range(1, total_pages + 1):
#       7     response = session.get(
#       8         "https://api.themoviedb.org/3/movie/top_rated",
#       9         params={
#    (...)     14         timeout=10
#      15     )
#      17     data = response.json()
#
# NameError: name 'total_pages' is not defined
